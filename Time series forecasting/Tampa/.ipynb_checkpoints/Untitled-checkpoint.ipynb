# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import folium
from scipy.stats import pearsonr
from folium import plugins
from folium.plugins import HeatMap
from folium.plugins import HeatMapWithTime
import calendar
from matplotlib.ticker import FuncFormatter
import datetime
import joblib
import xgboost as xgb
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
import statsmodels
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
data = pd.read_excel('consumption.xlsx')
data.head()
# Out:
#      Month  Year Day of the Month Rain fall,Inches  \
# 0  January  2017                1                0
# 1  January  2017                2                0
# 2  January  2017                3                0
# 3  January  2017                4                0
# 4  January  2017                5                0
#
#   TotalTreated water leaving plant,MG Hours Plant in operation  \
# 0                               15.38                       24
# 1                               15.56                       24
# 2                               15.74                       24
# 3                               16.02                       24
# 4                               15.25                       24
#
#   Total Raw water to plant,MG Compliance with permitted capacity?  \
# 0                       27.14                                 yes
# 1                       27.13                                 yes
# 2                       27.14                                 yes
# 3                       26.83                                 yes
# 4                       26.63                                 yes
#
#   Backwas,Thousand Gallons Peak demand into distribution,MDG  ...  \
# 0                     3043                             15.29  ...
# 1                     3076                             15.47  ...
# 2                     3110                              15.6  ...
# 3                     3095                             15.62  ...
# 4                     3038                              15.5  ...
#
#   Measuremnt Recorded ≥ Measuremnt Required?  \
# 0                                        Yes
# 1                                        Yes
# 2                                        Yes
# 3                                        Yes
# 4                                        Yes
#
#   № Measuremnt ≤ SpecifiedTreatmentTeachique Limit  \
# 0                                                6
# 1                                                6
# 2                                                6
# 3                                                6
# 4                                                6
#
#   № Measuremmt > Never Exceed Limit Average Daily Turbidity,NTU  \
# 0                                 0                        0.02
# 1                                 0                        0.02
# 2                                 0                        0.02
# 3                                 0                        0.02
# 4                                 0                        0.02
#
#   Maximum DailyTurbidity,NTU Log Inactivation,Giardia Giardia Compliance?  \
# 0                       0.02                     7.54                 Yes
# 1                       0.02                     6.31                 Yes
# 2                       0.02                      6.8                 Yes
# 3                       0.02                     8.72                 Yes
# 4                       0.02                     8.86                 Yes
#
#   Log Inactivation,Viruses Virus Compliance?  \
# 0                   472.74               Yes
# 1                   405.58               Yes
# 2                   439.79               Yes
# 3                   468.74               Yes
# 4                   443.77               Yes
#
#   Emergency or Abnormal Operating Conditions,Repairor Maintenance Work that InvolvesTaking Water System Components Out of Operation
# 0                    Producing -TBW > Finished Water
# 1                   Producing - TBW > Finished Water
# 2                    Producing -TBW > Finished Water
# 3                    Producing -TBW > Finished Water
# 4                    Producing -TBW > Finished Water
#
# [5 rows x 22 columns]

# %%
data1 = pd.read_csv('Cleaned.csv')
data1.head()
# Out:
#          Date  Adjusted Daily Consumption, Kwh
# 0  01/01/2017                           153910
# 1  02/01/2017                           153910
# 2  03/01/2017                           153910
# 3  04/01/2017                           153910
# 4  05/01/2017                           153910

# %%
column_names = data.columns.tolist()

# Print the list of column names
print("List of columns in the DataFrame:")
print(column_names)
# Out:
# List of columns in the DataFrame:
# ['Month', 'Year', 'Day of the Month', 'Rain fall,Inches', 'TotalTreated water leaving plant,MG', 'Hours Plant in operation', 'Total Raw water to plant,MG', 'Compliance with permitted capacity?', 'Backwas,Thousand Gallons', 'Peak demand into distribution,MDG', 'Nomeasurements Recorded', 'No Measuremnts Required', 'Measuremnt Recorded ≥ Measuremnt Required?', '№ Measuremnt ≤ SpecifiedTreatmentTeachique Limit', '№ Measuremmt > Never Exceed Limit', 'Average Daily Turbidity,NTU', 'Maximum DailyTurbidity,NTU', 'Log Inactivation,Giardia', 'Giardia Compliance?', 'Log Inactivation,Viruses', 'Virus Compliance?', 'Emergency or Abnormal Operating Conditions,Repairor Maintenance Work that InvolvesTaking Water System Components Out of Operation']

# %%
# List of columns to check for non-numeric values
columns_to_check = ['Rain fall,Inches', 'TotalTreated water leaving plant,MG',  'Hours Plant in operation', 'Total Raw water to plant,MG',
                    'Backwas,Thousand Gallons', 'Peak demand into distribution,MDG', 'Nomeasurements Recorded',
                    'No Measuremnts Required',  'Average Daily Turbidity,NTU', 'Maximum DailyTurbidity,NTU', 'Log Inactivation,Giardia',
                     'Log Inactivation,Viruses']
# Convert to numeric, coercing non-numeric to NaN
for col in columns_to_check:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Drop rows where any of the specified columns are NaN
data.dropna(subset=columns_to_check, inplace=True)

# Reset the index
data.reset_index(drop=True, inplace=True)

# %%
column_data_types = data.dtypes

# Print the data types
print("Data types of each column in the DataFrame:")
print(column_data_types)
# Out:
# Data types of each column in the DataFrame:
# Month                                                                                                                                 object
# Year                                                                                                                                   int64
# Day of the Month                                                                                                                      object
# Rain fall,Inches                                                                                                                     float64
# TotalTreated water leaving plant,MG                                                                                                  float64
# Hours Plant in operation                                                                                                             float64
# Total Raw water to plant,MG                                                                                                          float64
# Compliance with permitted capacity?                                                                                                   object
# Backwas,Thousand Gallons                                                                                                             float64
# Peak demand into distribution,MDG                                                                                                    float64
# Nomeasurements Recorded                                                                                                              float64
# No Measuremnts Required                                                                                                              float64
# Measuremnt Recorded ≥ Measuremnt Required?                                                                                            object
# № Measuremnt ≤ SpecifiedTreatmentTeachique Limit                                                                                      object
# № Measuremmt > Never Exceed Limit                                                                                                     object
# Average Daily Turbidity,NTU                                                                                                          float64
# Maximum DailyTurbidity,NTU                                                                                                           float64
# Log Inactivation,Giardia                                                                                                             float64
# Giardia Compliance?                                                                                                                   object
# Log Inactivation,Viruses                                                                                                             float64
# Virus Compliance?                                                                                                                     object
# Emergency or Abnormal Operating Conditions,Repairor Maintenance Work that InvolvesTaking Water System Components Out of Operation     object
# dtype: object

# %%
# Correct the year naming issue (changing "20222" to "2022")
data['Year'] = data['Year'].replace(20222, 2022)

# Convert Month, Day, and Year columns to a datetime format
data['Date'] = pd.to_datetime(data['Year'].astype(str) + '-' + data['Month'].astype(str) + '-' + data['Day of the Month'].astype(str), errors='coerce')

# %%
# Extract the required columns
data = data[['Date',  'Year', 'Month', 'Day of the Month', 'Rain fall,Inches', 'TotalTreated water leaving plant,MG',  'Hours Plant in operation', 'Total Raw water to plant,MG',
                    'Backwas,Thousand Gallons', 'Peak demand into distribution,MDG', 'Nomeasurements Recorded',
                    'No Measuremnts Required',  'Average Daily Turbidity,NTU', 'Maximum DailyTurbidity,NTU', 'Log Inactivation,Giardia',
                     'Log Inactivation,Viruses']]

# Display the extracted data
data.head().
# Out:
#         Date  Year    Month Day of the Month  Rain fall,Inches  \
# 0 2017-01-01  2017  January                1               0.0
# 1 2017-01-02  2017  January                2               0.0
# 2 2017-01-03  2017  January                3               0.0
# 3 2017-01-04  2017  January                4               0.0
# 4 2017-01-05  2017  January                5               0.0
#
#    TotalTreated water leaving plant,MG  Hours Plant in operation  \
# 0                                15.38                      24.0
# 1                                15.56                      24.0
# 2                                15.74                      24.0
# 3                                16.02                      24.0
# 4                                15.25                      24.0
#
#    Total Raw water to plant,MG  Backwas,Thousand Gallons  \
# 0                        27.14                    3043.0
# 1                        27.13                    3076.0
# 2                        27.14                    3110.0
# 3                        26.83                    3095.0
# 4                        26.63                    3038.0
#
#    Peak demand into distribution,MDG  Nomeasurements Recorded  \
# 0                              15.29                      6.0
# 1                              15.47                      6.0
# 2                              15.60                      6.0
# 3                              15.62                      6.0
# 4                              15.50                      6.0
#
#    No Measuremnts Required  Average Daily Turbidity,NTU  \
# 0                      6.0                         0.02
# 1                      6.0                         0.02
# 2                      6.0                         0.02
# 3                      6.0                         0.02
# 4                      6.0                         0.02
#
#    Maximum DailyTurbidity,NTU  Log Inactivation,Giardia  \
# 0                        0.02                      7.54
# 1                        0.02                      6.31
# 2                        0.02                      6.80
# 3                        0.02                      8.72
# 4                        0.02                      8.86
#
#    Log Inactivation,Viruses
# 0                    472.74
# 1                    405.58
# 2                    439.79
# 3                    468.74
# 4                    443.77

# %%
# Convert the 'Date' column in data1 to datetime format
data1['Date'] = pd.to_datetime(data1['Date'])

# Now you can perform the merge
data = pd.merge(data, data1, on='Date', how='inner')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/02/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '31/03/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/05/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '31/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '31/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/02/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/03/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/03/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# ...
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '31/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '13/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '14/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '15/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '16/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '17/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '18/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '19/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '20/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '21/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '22/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '23/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '24/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '25/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '26/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '27/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '28/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '29/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11428\3107944606.py:2: UserWarning: Parsing '30/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data1['Date'] = pd.to_datetime(data1['Date'])

# %%
column_data_types = data.dtypes

# Print the data types
print("Data types of each column in the DataFrame:")
print(column_data_types)
# Out:
# Data types of each column in the DataFrame:
# Date                                   datetime64[ns]
# Year                                            int64
# Month                                          object
# Day of the Month                               object
# Rain fall,Inches                              float64
# TotalTreated water leaving plant,MG           float64
# Hours Plant in operation                      float64
# Total Raw water to plant,MG                   float64
# Backwas,Thousand Gallons                      float64
# Peak demand into distribution,MDG             float64
# Nomeasurements Recorded                       float64
# No Measuremnts Required                       float64
# Average Daily Turbidity,NTU                   float64
# Maximum DailyTurbidity,NTU                    float64
# Log Inactivation,Giardia                      float64
# Log Inactivation,Viruses                      float64
# Adjusted Daily Consumption, Kwh                 int64
# dtype: object

# %%
data = pd.get_dummies(data, columns=['Month'], drop_first=True)

# Convert 'Day of the Month' to integer if it's an object
if data['Day of the Month'].dtype == 'object':
    data['Day of the Month'] = data['Day of the Month'].astype(int)

# %%
# Check the data types of each column
print('Data types of each column in the DataFrame:')
print(data.dtypes)

# Check for missing values
print('\nMissing values in each column:')
print(data.isnull().sum())

# Display basic statistics
print('\nBasic statistics:')
print(data.describe())
# Out:
# Data types of each column in the DataFrame:
# Date                                   datetime64[ns]
# Year                                            int64
# Day of the Month                                int32
# Rain fall,Inches                              float64
# TotalTreated water leaving plant,MG           float64
# Hours Plant in operation                      float64
# Total Raw water to plant,MG                   float64
# Backwas,Thousand Gallons                      float64
# Peak demand into distribution,MDG             float64
# Nomeasurements Recorded                       float64
# No Measuremnts Required                       float64
# Average Daily Turbidity,NTU                   float64
# Maximum DailyTurbidity,NTU                    float64
# Log Inactivation,Giardia                      float64
# Log Inactivation,Viruses                      float64
# Adjusted Daily Consumption, Kwh                 int64
# Month_December                                  uint8
# Month_Feb                                       uint8
# Month_February                                  uint8
# Month_January                                   uint8
# Month_July                                      uint8
# Month_June                                      uint8
# Month_March                                     uint8
# Month_May                                       uint8
# Month_November                                  uint8
# dtype: object
#
# Missing values in each column:
# Date                                   0
# Year                                   0
# Day of the Month                       0
# Rain fall,Inches                       0
# TotalTreated water leaving plant,MG    0
# Hours Plant in operation               0
# Total Raw water to plant,MG            0
# Backwas,Thousand Gallons               0
# Peak demand into distribution,MDG      0
# Nomeasurements Recorded                0
# No Measuremnts Required                0
# Average Daily Turbidity,NTU            0
# Maximum DailyTurbidity,NTU             0
# Log Inactivation,Giardia               0
# Log Inactivation,Viruses               0
# Adjusted Daily Consumption, Kwh        0
# Month_December                         0
# Month_Feb                              0
# Month_February                         0
# Month_January                          0
# Month_July                             0
# Month_June                             0
# Month_March                            0
# Month_May                              0
# Month_November                         0
# dtype: int64
#
# Basic statistics:
#               Year  Day of the Month  Rain fall,Inches  \
# count   877.000000        877.000000        877.000000
# mean   2020.054732         16.070696          0.081477
# std       1.842972          8.484852          0.339261
# min    2017.000000          1.000000          0.000000
# 25%    2019.000000          9.000000          0.000000
# 50%    2020.000000         17.000000          0.000000
# 75%    2022.000000         23.000000          0.000000
# max    2023.000000         31.000000          3.500000
#
#        TotalTreated water leaving plant,MG  Hours Plant in operation  \
# count                           877.000000                877.000000
# mean                            157.519874                 23.156784
# std                            4251.478767                  3.954445
# min                               0.000000                  0.000000
# 25%                              12.100000                 24.000000
# 50%                              14.350000                 24.000000
# 75%                              15.836900                 24.000000
# max                          125918.000000                 24.000000
#
#        Total Raw water to plant,MG  Backwas,Thousand Gallons  \
# count                   877.000000                877.000000
# mean                    409.668890               2556.636563
# std                   11425.442621                874.062610
# min                       6.740230                  1.790000
# 25%                      20.255900               2445.000000
# 50%                      25.580000               2804.000000
# 75%                      27.005819               3018.620200
# max                  338379.000000               3675.737500
#
#        Peak demand into distribution,MDG  Nomeasurements Recorded  \
# count                         877.000000               877.000000
# mean                          304.438692                 5.976055
# std                          6063.640667                 0.275518
# min                             0.047500                 2.000000
# 25%                            12.312700                 6.000000
# 50%                            14.968500                 6.000000
# 75%                            16.203200                 6.000000
# max                        127892.000000                 6.000000
#
#        No Measuremnts Required  ...  Adjusted Daily Consumption, Kwh  \
# count               877.000000  ...                       877.000000
# mean                  5.842645  ...                    122161.191562
# std                   0.885116  ...                     72051.841062
# min                   0.000000  ...                         0.000000
# 25%                   6.000000  ...                     81950.000000
# 50%                   6.000000  ...                    134468.000000
# 75%                   6.000000  ...                    192656.000000
# max                   6.000000  ...                    259874.000000
#
#        Month_December   Month_Feb  Month_February  Month_January  Month_July  \
# count      877.000000  877.000000      877.000000     877.000000  877.000000
# mean         0.119726    0.045610        0.099202       0.196123    0.011403
# std          0.324826    0.208757        0.299103       0.397289    0.106233
# min          0.000000    0.000000        0.000000       0.000000    0.000000
# 25%          0.000000    0.000000        0.000000       0.000000    0.000000
# 50%          0.000000    0.000000        0.000000       0.000000    0.000000
# 75%          0.000000    0.000000        0.000000       0.000000    0.000000
# max          1.000000    1.000000        1.000000       1.000000    1.000000
#
#        Month_June  Month_March   Month_May  Month_November
# count  877.000000   877.000000  877.000000      877.000000
# mean     0.051311     0.174458    0.119726        0.027366
# std      0.220758     0.379720    0.324826        0.163241
# min      0.000000     0.000000    0.000000        0.000000
# 25%      0.000000     0.000000    0.000000        0.000000
# 50%      0.000000     0.000000    0.000000        0.000000
# 75%      0.000000     0.000000    0.000000        0.000000
# max      1.000000     1.000000    1.000000        1.000000
#
# [8 rows x 24 columns]

# %%
# Removing outliers beyond 99th percentile
for col in ['TotalTreated water leaving plant,MG', 'Total Raw water to plant,MG', 'Peak demand into distribution,MDG']:
    cap = data[col].quantile(0.99)
    data = data[data[col] <= cap]

# %%
# Checking for non-numeric values

# Function to check if a string contains only digits and periods
def check_string(value):
    for char in str(value):
        if char not in '1234567890.':
            return False
    return True

# Dictionary to store columns with non-integer or non-period characters
columns_with_non_integers = {}

# Loop through each column that is supposed to be numeric after preprocessing
for col in data:  # Replace with your actual numeric columns
    if col != "Date":
      # Check each value in the column
      for value in data[col]:
          if not check_string(value):
              if col not in columns_with_non_integers:
                  columns_with_non_integers[col] = []
              columns_with_non_integers[col].append(value)

# Display the columns and their non-integer values
for col, values in columns_with_non_integers.items():
    print(f"Column '{col}' has non-integer values: {values[:10]}...")  # Display only the first 10 non-integer values

# %%
# Importing required libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from statsmodels.tsa.statespace.sarimax import SARIMAX
from math import sqrt

# %%
# Split sizes
train_size = int(len(data) * 0.5)  # 50% for training

# Train-Test Split
train, test = data[:train_size], data[train_size:]

# Prepare data for machine learning models for actual values

# Training data
X_train_actual = train.drop(['Date', 'TotalTreated water leaving plant,MG', 'Adjusted Daily Consumption, Kwh'], axis=1)
y_train_treated_actual = train['TotalTreated water leaving plant,MG']
y_train_energy_actual = train['Adjusted Daily Consumption, Kwh']

# Test data
X_test_actual = test.drop(['Date', 'TotalTreated water leaving plant,MG', 'Adjusted Daily Consumption, Kwh'], axis=1)
y_test_treated_actual = test['TotalTreated water leaving plant,MG']
y_test_energy_actual = test['Adjusted Daily Consumption, Kwh']

print("Training set size:", len(X_train_actual))
print("Test set size:", len(X_test_actual))
# Out:
# Training set size: 426
# Test set size: 427

# %%
# Define a function for training machine learning models
def train_ml_model(model, X_train, y_train):
    model.fit(X_train, y_train)
    return model

# Define a function for training SARIMA models
def train_sarima_model(y_train, order, seasonal_order):
    try:
        sarima_model = SARIMAX(y_train, order=order, seasonal_order=seasonal_order)
        sarima_fit = sarima_model.fit(disp=False)
        return sarima_fit
    except Exception as e:
        print("Error fitting SARIMA model:", str(e))
        return None

# Machine Learning Model Training for Treated Water
rf_model_treated = train_ml_model(RandomForestRegressor(), X_train_actual, y_train_treated_actual)
gb_model_treated = train_ml_model(GradientBoostingRegressor(), X_train_actual, y_train_treated_actual)

# Machine Learning Model Training for Energy Consumption
rf_model_energy = train_ml_model(RandomForestRegressor(), X_train_actual, y_train_energy_actual)
gb_model_energy = train_ml_model(GradientBoostingRegressor(), X_train_actual, y_train_energy_actual)

# SARIMA Model Training for Treated Water
sarima_order = (1, 1, 1)
sarima_seasonal_order = (1, 1, 1, 12)
sarima_fit_treated = train_sarima_model(y_train_treated_actual, sarima_order, sarima_seasonal_order)

# SARIMA Model Training for Energy Consumption
sarima_fit_energy = train_sarima_model(y_train_energy_actual, sarima_order, sarima_seasonal_order)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Making Predictions for Actual Values on Test Set
rf_pred_treated_test = rf_model_treated.predict(X_test_actual)
gb_pred_treated_test = gb_model_treated.predict(X_test_actual)
rf_pred_energy_test = rf_model_energy.predict(X_test_actual)
gb_pred_energy_test = gb_model_energy.predict(X_test_actual)

# Making SARIMA Predictions for Actual Values on Test Set
sarima_pred_treated_test = sarima_fit_treated.predict(start=len(y_train_treated_actual), end=len(y_train_treated_actual) + len(y_test_treated_actual) - 1, dynamic=True)
sarima_pred_energy_test = sarima_fit_energy.predict(start=len(y_train_energy_actual), end=len(y_train_energy_actual) + len(y_test_energy_actual) - 1, dynamic=True)

# Convert SARIMA predictions to numpy arrays for consistency
sarima_pred_treated_test = np.array(sarima_pred_treated_test)
sarima_pred_energy_test = np.array(sarima_pred_energy_test)

# Ensemble Predictions for Actual Values on Test Set
treated_test_outputs = [rf_pred_treated_test, gb_pred_treated_test, sarima_pred_treated_test]
energy_test_outputs = [rf_pred_energy_test, gb_pred_energy_test, sarima_pred_energy_test]
ensemble_pred_treated_test = np.mean(treated_test_outputs, axis=0)
ensemble_pred_energy_test = np.mean(energy_test_outputs, axis=0)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt
import numpy as np

def error(y_true, y_pred, threshold=0.5):
    """
    Calculate the error rate based on a given threshold.
    The function returns the proportion of predictions that are off by more than the threshold.
    """
    return np.mean(np.abs(y_true - y_pred) > threshold)

def evaluate_predictions(y_true, y_pred, model_name):
    """
    Evaluate and print RMSE, MAE, and Error Rate for a given model's predictions.
    """
    rmse = sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    err_rate = error(y_true, y_pred)
    
    print(f"=== {model_name} ===")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"Error Rate: {err_rate:.4f}\n")
    return rmse, mae, err_rate

def main():
    # Evaluating Water Flow Predictions
    print("Evaluations for Water Flow:\n")
    evaluate_predictions(y_test_treated_actual, rf_pred_treated_test, "Random Forest")
    evaluate_predictions(y_test_treated_actual, gb_pred_treated_test, "Gradient Boosting")
    evaluate_predictions(y_test_treated_actual, sarima_pred_treated_test, "SARIMA")
    evaluate_predictions(y_test_treated_actual, ensemble_pred_treated_test, "Ensemble")
    
    # Evaluating Energy Consumption Predictions
    print("Evaluations for Energy Consumption:\n")
    evaluate_predictions(y_test_energy_actual, rf_pred_energy_test, "Random Forest")
    evaluate_predictions(y_test_energy_actual, gb_pred_energy_test, "Gradient Boosting")
    evaluate_predictions(y_test_energy_actual, sarima_pred_energy_test, "SARIMA")
    evaluate_predictions(y_test_energy_actual, ensemble_pred_energy_test, "Ensemble")

# Run the evaluations
main()
# Out:
# Evaluations for Water Flow:
#
# === Random Forest ===
# RMSE: 1.4451
# MAE: 0.6976
# Error Rate: 0.2927
#
# === Gradient Boosting ===
# RMSE: 1.5826
# MAE: 0.8255
# Error Rate: 0.3115
#
# === SARIMA ===
# RMSE: 3.9810
# MAE: 2.7640
# Error Rate: 0.7471
#
# === Ensemble ===
# RMSE: 2.0670
# MAE: 1.3109
# Error Rate: 0.6511
#
# Evaluations for Energy Consumption:
#
# === Random Forest ===
# RMSE: 58907.3548
# MAE: 44818.4326
# Error Rate: 0.9977
#
# === Gradient Boosting ===
# RMSE: 61818.4116
# MAE: 50209.0551
# Error Rate: 1.0000
#
# === SARIMA ===
# RMSE: 147498.6281
# MAE: 124239.0865
# Error Rate: 1.0000
#
# === Ensemble ===
# RMSE: 58209.6322
# MAE: 43675.6476
# Error Rate: 1.0000
